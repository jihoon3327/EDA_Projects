# %%
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_columns', 150)
# Out:
# pandas version:  1.2.3

# %%
import missingno as msno
df_1 = pd.read_csv("./df_pfpp.csv")
df_2 = pd.read_csv("./df_agg.csv")
df_3 = pd.read_csv("./kill_df.csv")
df_4 = pd.read_csv("./df_4.csv")

# %% [markdown]
# ### 데이터_1 column 설명
# - Id - user id
# - assists - 팀원이 죽인 적들 중에 데미지를 가해 도운 횟수
# - boosts - 사용된 부스트 아이템의 개수
# - damageDealt - 가한 데미지의 총합. 스스로 가한 데미지는 제외.
# - DBNOs - 기절시킨 적의 수
# - headshotKills - 헤드샷으로 죽은 적의 수
# - heals - 사용된 치료 아이템의 개수
# - killPlace - 매치에서 킬 수 기준으로 집계한 등수
# - killPoints - 킬 랭킹 기반의 포인트
# - kills - 죽인 적의 횟수
# - killStreaks - 짧은 시간 내에 가장 많이 적을 죽인 횟수
# - LongestKill - 가장 먼 거리에서 적을 죽인 거리
# - MatchDuration - 게임 Runtime
# - maxPlace - 매치 내에서 가장 낮은 등수. 가끔 데이터가 등수를 거르기도해서 때문에 총 그룹의 수와 일치하지 않을 수 있음
# - numGroups - 매치 내에서 총 그룹의 수
# - Rankpoint - 현재 랭킹포인트
# - revives - 유저가 팀원을 살린 횟수
# - rideDistance - 차량을 통해 이동한 총거리 (미터)
# - roadKills - 차량 탑승 도중에 적을 죽인 횟수
# - swimDistance - 유저가 수영한 총거리 (미터)
# - teamKills - 유저가 같은 팀원을 죽인 횟수
# - vehicleDestroys - 이동차량을 파괴한 횟수
# - walkDistance - 걸어서 이동한 총거리 (미터)
# - weaponsAcquired - 총 획득한 무기의 수
# - winPoints - 승리에 기반한 유저의 랭킹 포인트
# - winPlacePerc - 백분위수에 기반한 타겟의 예측. 1은 1등을 의미하며 0은 마지막 등수를 의미한다.

# %%
df_1.to_csv("./df_1.csv")
df_2.to_csv("./df_2.csv")
df_3.to_csv("./df_3.csv")
df_4_Solo.to_csv("./df_4_Solo.csv")
df_4_Duo.to_csv("./df_4_Duo.csv")
df_4_Squad.to_csv("./df_4_Squad.csv")

# %%
df_1
# Out:
#                      Id  assists  boosts  damageDealt  DBNOs  headshotKills  \
# 0        00000160737ebf        0       1         0.00      0              0
# 1        000004df44d81a        0       0         0.00      0              0
# 2        0000053e9d70a9        0       2       183.00      0              1
# 3        00000864f15972        0       4       360.20      1              1
# 4        0000088423bc95        0       2        54.17      1              0
# ...                 ...      ...     ...          ...    ...            ...
# 6381135  fffff45a84de88        0       0        26.90      0              0
# 6381136  fffff4eb4adf0a        1       4       394.20      3              0
# 6381137  fffff8e6c6be6d        0       0        12.60      0              0
# 6381138  fffffddae4e502        0       6       362.40      4              2
# 6381139  ffffff978f99ee        0       0         0.00      0              0
#
# ...

# %% [markdown]
# ### 데이터_2 column 설명
#
# - player_name : user id
# - player assists : 적을 죽이는데 같이 데미이를 입힌 수
# - player_dbno : 적을 기절시킨 수
# - player_dist_ride : 이동수단을 이용하여 움직인 거리
# - player_dist_walk : 걸어다닌 이동거리
# - player_kills : 적을 죽인 수
# - player_survive_time : 플레이어 생존시간

# %%
df_2
# Out:
#               player_name  game_size  party_size  player_assists  player_dbno  \
# 0          0----erhu----0  49.250000    2.000000        0.000000        0.250
# 1          0---HaMMaN---0  88.083333    1.250000        0.000000        0.000
# 2              0---JK---0  97.000000    1.000000        0.000000        0.000
# 3             0---Wan---0  30.333333    3.333333        0.666667        2.000
# 4                0---noon  31.875000    3.250000        0.500000        2.500
# ...                   ...        ...         ...             ...          ...
# 7669683  zzzzzzzzzzzzzzzf  41.333333    2.666667        1.000000        3.000
# 7669684  zzzzzzzzzzzzzzzh  48.000000    2.000000        0.000000        0.000
# 7669685  zzzzzzzzzzzzzzzj  43.875000    3.250000        0.250000        0.875
# 7669686  zzzzzzzzzzzzzzzv  29.000000    4.000000        0.000000        1.000
# 7669687  zzzzzzzzzzzzzzzx  28.000000    4.000000        2.000000        7.000
#
# ...

# %% [markdown]
# ### 데이터_3 설명
# - killed_by : 상대를 죽이는데 사용한 총
# - id : id
# - placement : 해당 판 등수
# - map : 맵 종류
# - time : 생존시간

# %%
df_3
# Out:
#           Unnamed: 0     killed_by             id  placement      map  time
# 0                  0          M249  0932313woaini        7.0  MIRAMAR  1209
# 1                  1        Kar98k     arunrunrun        6.0  MIRAMAR  1096
# 2                  2  Down and Out      Rabbit812        6.0  MIRAMAR  1096
# 3                  3  Down and Out  0932313woaini        7.0  MIRAMAR  1209
# 4                  4        SCAR-L      sa11y1126        3.0  MIRAMAR  1793
# ...              ...           ...            ...        ...      ...   ...
# 11640850    11640850           AKM      Schrade03        7.0  ERANGEL   284
# 11640851    11640851         M16A4   ManzAreFried        2.0  ERANGEL   281
# 11640852    11640852           AKM   Mint_Pudding       18.0  ERANGEL   219
# 11640853    11640853           AKM       conemeli        8.0  ERANGEL   221
# 11640854    11640854  Down and Out       JesseMay        6.0  ERANGEL   992
#
# [11640855 rows x 6 columns]

# %%
re.findall("solo_[0-9a-zA-Z]{0,30}", str(df_4.columns))
# Out:
# ['solo_KillDeathRatio',
#  'solo_WinRatio',
#  'solo_TimeSurvived',
#  'solo_RoundsPlayed',
#  'solo_Wins',
#  'solo_WinTop10Ratio',
#  'solo_Top10s',
#  'solo_Top10Ratio']

# %%
import re

# %%
df_4
# Out:
#          player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0          BreakNeck        4405                 3.14          17.65
# 1          Blackwalk        8199                 4.41          18.18
# 2      mercedes_benz        4454                 3.60           0.00
# 3               DORA        7729                14.00          50.00
# 4            n2tstar           0                10.50          33.33
# ...              ...         ...                  ...            ...
# 87893      SaikoMene       87710                 1.05           0.00
# 87894        KARUKOR       22783                 1.61           4.65
# 87895      Dertydann      178547                 1.00           0.00
# 87896       Neferhor      126589                 5.10          16.67
# 87897  pepperedangus       66362                 0.83           1.38
#
#        solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# ...

# %%
df_4_solo
# Out:
#          player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0          BreakNeck        4405                 3.14          17.65
# 1          Blackwalk        8199                 4.41          18.18
# 2      mercedes_benz        4454                 3.60           0.00
# 3               DORA        7729                14.00          50.00
# 4            n2tstar           0                10.50          33.33
# ...              ...         ...                  ...            ...
# 87893      SaikoMene       87710                 1.05           0.00
# 87894        KARUKOR       22783                 1.61           4.65
# 87895      Dertydann      178547                 1.00           0.00
# 87896       Neferhor      126589                 5.10          16.67
# 87897  pepperedangus       66362                 0.83           1.38
#
#        solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# ...

# %%
a = df_4.iloc[:,0:2]
b = df_4.iloc[:,52:102]
c = df_4.iloc[:,102:152]

ls1 = [a,b]
ls2 = [a,c]

# %%
df_4_solo.drop(columns="tracker_id",inplace=True)

# %%
df_4_Duo.drop(columns="tracker_id",inplace=True)

# %%
df_4_Squad.drop(columns="tracker_id",inplace=True)

# %% [markdown]
# ### df_4 설명
# - player_name : 플레이어
# - solo_KillDeathRatio : kill/death
# - solo_WinRatio : 승리 비율(%)
# - solo_TimeSurvived : 총 생존 시간(s)
# - solo_RoundsPlayed : 총 경기 수
# - solo_Wins : 총 승리 횟수
# - solo_WinTop10Ratio : top10 진입 시 승리 비율
# - solo_Top10s : 총 top10 진입 횟수
# - solo_Top10Ratio : top10 진입 비율
# - solo_Losses : 총 죽음 수
# - solo_Rating : 평균 실력지표
# - solo_BestRating : 시즌 베스트 실력지표
# - solo_DamagePg : 게임 당 상대에게 데미지를 가한 양
# - solo_HeadshotKillsPg : 게임 당 해드샷 횟수
# - solo_HealsPg : 게임 당 체력회복 아이템으로 체력을 회복한 양
# - solo_KillsPg : 게임 당 상대를 죽인 횟수
# - solo_MoveDistancePg : 게임 당 움직인 거리
# - solo_RevivesPg : 게임 당 다시 살아난 횟수
# - solo_RoadKillsPg : 게임 당 로드킬 횟수
# - solo_TeamKillsPg : 게임 당 팀킬 횟수
# - solo_TimeSurvivedPg : 게임 당 생존 시간
# - solo_Top10sPg : 게임 당 top10 진입 횟수
# - solo_Kills : 총 킬 횟수
# - solo_Assists : 총 어시스트 수
# - solo_Suicides : 총 자살 횟수
# - solo_TeamKills : 총 팀킬 횟수
# - solo_HeadshotKills : 총 헤드샷 수
# - solo_HeadshotKillRatio : 킬 중 헤드샷 비율
# - solo_VehicleDestroys : 총 탈것 파괴 횟수
# - solo_RoadKills : 총 로드킬 수
# - solo_DailyKills : 일간 킬 횟수
# - solo_WeeklyKills : 주간 킬 횟수
# - solo_RoundMostKills : 한판에 기록한 최대 킬 수
# - solo_MaxKillStreaks : 최대 연속 킬 수
# - solo_WeaponAcquired : drop 예정
# - solo_Days : 접속해서 solo를 플레이한 날의 수
# - solo_LongestTimeSurvived : 가장 긴 생존 시간
# - solo_MostSurvivalTime : 최대 생존시간
# - solo_AvgSurvivalTime : 경기당 평균 생존시간
# - solo_WinPoints : 총 우승포인트
# - solo_WalkDistance : 총 걸은 거리
# - solo_RideDistance : 총 차 주행거리
# - solo_MoveDistance : 총 이동거리
# - solo_AvgWalkDistance : 경기당 평균 걸은 거리
# - solo_AvgRideDistance : 경기당 평균 차 주행거리
# - solo_Longestkill : 킬 최장거리
# - solo_Heals : 회복 아이템 사용 횟수
# - solo_Revives :부활 횟수
# - solo_Boosts : 아이템으로 부스트게이지를 회복한 수
# - solo_DamageDealt : 총 적에게 준 데미지
# - solo_DBNOs : 적을 기절시킨 횟수

# %%
df_4_Solo
# Out:
#          player_name  solo_KillDeathRatio  solo_WinRatio  solo_TimeSurvived  \
# 0          BreakNeck                 3.14          17.65           18469.14
# 1          Blackwalk                 4.41          18.18           33014.86
# 2      mercedes_benz                 3.60           0.00            4330.44
# 3               DORA                14.00          50.00           13421.82
# 4            n2tstar                10.50          33.33            9841.04
# ...              ...                  ...            ...                ...
# 87893      SaikoMene                 1.05           0.00           48273.92
# 87894        KARUKOR                 1.61           4.65           49006.75
# 87895      Dertydann                 1.00           0.00           14272.20
# 87896       Neferhor                 5.10          16.67           58518.86
# 87897  pepperedangus                 0.83           1.38          198473.81
#
# ...

# %%
df_4_Duo
# Out:
#          player_name  duo_KillDeathRatio  duo_WinRatio  duo_TimeSurvived  \
# 0          BreakNeck                6.50         33.33          21913.81
# 1          Blackwalk                4.56         35.71          17765.43
# 2      mercedes_benz                6.55         35.29          23449.22
# 3               DORA                8.00         66.67           4196.37
# 4            n2tstar                5.03         25.71         142571.50
# ...              ...                 ...           ...               ...
# 87893      SaikoMene                1.00          7.14          24717.99
# 87894        KARUKOR                1.55          0.00          22581.61
# 87895      Dertydann                1.01          2.54         112808.56
# 87896       Neferhor                3.88         17.74         311229.68
# 87897  pepperedangus                0.75          1.11          82085.84
#
#        duo_RoundsPlayed  duo_Wins  duo_WinTop10Ratio  duo_Top10s  \
# ...

# %%
df_4_Squad
# Out:
#          player_name  squad_KillDeathRatio  squad_WinRatio  \
# 0          BreakNeck                  5.45           47.51
# 1          Blackwalk                  5.73           46.81
# 2      mercedes_benz                  6.08           47.34
# 3               DORA                  4.77           42.16
# 4            n2tstar                  5.70           46.39
# ...              ...                   ...             ...
# 87893      SaikoMene                  0.94            3.57
# 87894        KARUKOR                  1.42            8.70
# 87895      Dertydann                  0.90            1.46
# 87896       Neferhor                  2.88           15.95
# 87897  pepperedangus                  0.84            2.41
#
#        squad_TimeSurvived  squad_RoundsPlayed  squad_Wins  \
# 0              1064406.38                 642         305
# 1              1176986.52                 722         338
# 2              1166679.99                 733         347
# ...
